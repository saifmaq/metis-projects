# %%
# importing clean and customized data
import pickle
luther = pickle.load(open('bensondata.pkl','rb'))

# %%
import pickle
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
import numpy as np 
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
sns.set()

# %%
# adding categorical variables for genre and rating 
dummy = pd.get_dummies(luther['rating'])
dummy2 = pd.get_dummies(luther['genre'])
luther = pd.concat([luther,dummy,dummy2],axis=1)

# %%
luther.columns
# Out:
# Index(['domestic_gross', 'genre', 'movie_title', 'opening_weekend_gross',
#        'opening_weekend_percentage', 'rating', 'release_date', 'runtime',
#        'budget', 'worldwide_gross', 'spring', 'summer', 'winter', 'autumn',
#        'simultaneous_releases', 'G', 'NC-17', 'PG', 'PG-13', 'R', 'Unrated',
#        'Action', 'Adventure', 'Animation', 'Comedy', 'Concert', 'Crime',
#        'Documentary', 'Drama', 'Family', 'Fantasy', 'Horror', 'Independent',
#        'Musical', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western'],
#       dtype='object')

# %%
# making sure target variable is clean and accurate for our dataset 
luther['opening_weekend_percentage'] = (((luther['opening_weekend_gross']/luther['domestic_gross'])*100))
luther['opening_weekend_gross_log'] = np.log10(luther['opening_weekend_gross'])

# %%
with open('lutherinnit.pkl','wb') as picklefile:
    pickle.dump(luther,picklefile)

# %%
fig, ax = plt.subplots(figsize=a4_dims)

sns.distplot(y,ax=ax,color='green',axlabel='distribution of target variable')

# %%
features = ['opening_weekend_gross_log','runtime',
       'budget', 'spring', 'summer', 'winter', 'autumn',
       'simultaneous_releases', 'G', 'NC-17', 'PG', 'PG-13', 'R', 'Unrated',
       'Action', 'Adventure', 'Animation', 'Comedy', 'Concert', 'Crime',
       'Documentary', 'Drama', 'Family', 'Fantasy', 'Horror', 'Independent',
       'Musical', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']
X = luther.loc[:,features]
y = luther['opening_weekend_percentage']

# %%
#splitting data for training, validation and testing 
X, X_test, y, y_test = train_test_split(X, y, test_size=.2, random_state=9) 
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=.25, random_state=42)

# %%
#baseline linear regression 
model = sm.OLS(y, sm.add_constant(X))
results = model.fit()
ypred = results.predict(sm.add_constant(X))

# %%
print(results.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     opening_weekend_percentage   R-squared:                       0.538
# Model:                                    OLS   Adj. R-squared:                  0.532
# Method:                         Least Squares   F-statistic:                     86.39
# Date:                        Fri, 12 Oct 2018   Prob (F-statistic):               0.00
# Time:                                00:03:06   Log-Likelihood:                -7740.8
# No. Observations:                        2259   AIC:                         1.554e+04
# Df Residuals:                            2228   BIC:                         1.572e+04
# Df Model:                                  30
# Covariance Type:                    nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                       -65.1032      2.908    -22.386      0.000     -70.806     -59.400
# opening_weekend_gross_log    17.1925      0.476     36.102      0.000      16.259      18.126
# runtime                      -0.1122      0.011    -10.418      0.000      -0.133      -0.091
# budget                      5.61e-08   5.98e-09      9.382      0.000    4.44e-08    6.78e-08
# worldwide_gross           -3.312e-08   1.44e-09    -22.959      0.000    -3.6e-08   -3.03e-08
# spring                        2.5893      0.481      5.383      0.000       1.646       3.533
# summer                        0.4726      0.448      1.054      0.292      -0.406       1.352
# winter                     2.471e-15   1.01e-14      0.244      0.807   -1.74e-14    2.23e-14
# autumn                        2.3865      0.450      5.301      0.000       1.504       3.269
# simultaneous_releases        -0.2131      0.168     -1.270      0.204      -0.542       0.116
# G                           -15.4079      1.576     -9.775      0.000     -18.499     -12.317
# NC-17                        -5.6305      4.676     -1.204      0.229     -14.800       3.539
# PG                          -14.3213      1.312    -10.915      0.000     -16.894     -11.748
# PG-13                       -10.3412      1.353     -7.643      0.000     -12.995      -7.688
# R                           -10.5232      1.332     -7.899      0.000     -13.136      -7.911
# Unrated                      -8.8791      4.832     -1.838      0.066     -18.354       0.596
# Action                       -3.6447      0.702     -5.190      0.000      -5.022      -2.268
# Adventure                    -4.6441      0.717     -6.478      0.000      -6.050      -3.238
# Animation                    -6.1959      0.899     -6.894      0.000      -7.958      -4.433
# Comedy                       -6.8345      0.510    -13.399      0.000      -7.835      -5.834
# Concert                       5.9740      3.212      1.860      0.063      -0.325      12.273
# Crime                        -2.4622      1.663     -1.481      0.139      -5.723       0.799
# Documentary                  -9.5007      3.099     -3.066      0.002     -15.578      -3.423
# Drama                        -6.1229      0.577    -10.619      0.000      -7.254      -4.992
# Family                       -5.7577      2.213     -2.602      0.009     -10.098      -1.418
# Fantasy                      -1.4053      1.259     -1.116      0.264      -3.874       1.063
# Horror                        0.5091      0.698      0.729      0.466      -0.860       1.878
# Independent                   8.0203      0.924      8.677      0.000       6.208       9.833
# Musical                      -6.2127      1.571     -3.954      0.000      -9.294      -3.131
# Romance                      -4.7470      1.117     -4.252      0.000      -6.937      -2.557
# Sci-Fi                       -3.8565      2.191     -1.761      0.078      -8.152       0.439
# Thriller                     -5.4576      0.634     -8.610      0.000      -6.701      -4.215
# War                          -6.8696      1.804     -3.807      0.000     -10.408      -3.331
# Western                      -5.8950      1.587     -3.714      0.000      -9.008      -2.782
# ==============================================================================
# Omnibus:                       51.605   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.549
# Skew:                           0.307   Prob(JB):                     4.31e-14
# Kurtosis:                       3.526   Cond. No.                     1.33e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.56e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
np.sqrt(np.mean((y - ypred))**2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1032             with np.errstate(all='ignore'):
# -> 1033                 return na_op(lvalues, rvalues)
#    1034         except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1017                 mask = notna(x) & notna(y)
# -> 1018                 result[mask] = op(x[mask], com._values_from_object(y[mask]))
#    1019             else:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-236-a1d7362f7b22> in <module>()
# ----> 1 np.sqrt(np.mean((y - ypred))**2)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1067             rvalues = rvalues.values
#    1068
# -> 1069         result = safe_na_op(lvalues, rvalues)
#    1070         return construct_result(left, result,
#    1071                                 index=left.index, name=res_name, dtype=None)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# TypeError: ufunc 'subtract' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')

# %%
lm = LinearRegression()
model = lm.fit(X_train,y_train)
r2 = lm.score(X_val,y_val)
rmse = np.sqrt(np.mean((y_val - lm.predict(X_val))**2))
print("R2: " + str(r2) + " and RMSE: " + str(rmse))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1032             with np.errstate(all='ignore'):
# -> 1033                 return na_op(lvalues, rvalues)
#    1034         except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1017                 mask = notna(x) & notna(y)
# -> 1018                 result[mask] = op(x[mask], com._values_from_object(y[mask]))
#    1019             else:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-237-1d4bbb265465> in <module>()
#       2 model = lm.fit(X_train,y_train)
#       3 r2 = lm.score(X_val,y_val)
# ----> 4 rmse = np.sqrt(np.mean((y_val - lm.predict(X_val))**2))
#       5 print("R2: " + str(r2) + " and RMSE: " + str(rmse))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1067             rvalues = rvalues.values
#    1068
# -> 1069         result = safe_na_op(lvalues, rvalues)
#    1070         return construct_result(left, result,
#    1071                                 index=left.index, name=res_name, dtype=None)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# TypeError: ufunc 'subtract' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor


rf = RandomForestRegressor(n_estimators=1800)
rf.fit(X, y)
r2 = rf.score(, y_val)
RMSE = (rf.predict(X_val),y_val)
print(r2)
print(rmse)
# Out:
# 0.3768438545528535
# 7.712167349725559

# %%
ridge = RidgeCV(cv=5)
ridge = ridge.fit(X,y)
print(ridge.score(X,y))
print(np.sqrt(np.mean((y - ridge.predict(X))**2)))

print(ridge.score(X_test,y_test))
print(np.sqrt(np.mean((y_test - ridge.predict(X_test))**2)))
# Out:
# 0.43891147939561476
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.757831e-20
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.900702e-20
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.945628e-20
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.719991e-20
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.808501e-20
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.769687e-19
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.842991e-19
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.846539e-19
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.766272e-19
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.748710e-19
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.535558e-18
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.606129e-18
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.624314e-18
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.551409e-18
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.482507e-18
#   overwrite_a=True).T
# /Users/smaq/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.686373e-18
#   overwrite_a=True).T
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1032             with np.errstate(all='ignore'):
# -> 1033                 return na_op(lvalues, rvalues)
#    1034         except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1017                 mask = notna(x) & notna(y)
# -> 1018                 result[mask] = op(x[mask], com._values_from_object(y[mask]))
#    1019             else:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-239-3e78f5facafd> in <module>()
#       2 ridge = ridge.fit(X,y)
#       3 print(ridge.score(X,y))
# ----> 4 print(np.sqrt(np.mean((y - ridge.predict(X))**2)))
#       5
#       6 print(ridge.score(X_test,y_test))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1067             rvalues = rvalues.values
#    1068
# -> 1069         result = safe_na_op(lvalues, rvalues)
#    1070         return construct_result(left, result,
#    1071                                 index=left.index, name=res_name, dtype=None)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# TypeError: ufunc 'subtract' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')

# %%
poly = PolynomialFeatures(degree=2)

X_train_poly = poly.fit_transform(X_train)
X_val_poly = poly.transform(X_val)
X_test_poly = poly.transform(X_test)
lm_poly = LinearRegression()
lm_poly.fit(X_train_poly,y_train)
print(lm_poly.score(X_train_poly,y_train))
print(lm_poly.score(X_val_poly,y_val))
print(lm_poly.score(X_test_poly,y_test))
# Out:
# -1.302211726389868
# -22640.275212222023
# -2482.267815981362

# %%
gbm = GradientBoostingRegressor(n_estimators=1600, max_depth=3, learning_rate=.01)
gbm.fit(X_train, y_train)
gbm.score(X_test, y_test)
# Out:
# 0.5540637980821635

# %%
# Out:
# Empty DataFrame
# Columns: [domestic_gross, genre, movie_title, opening_weekend_gross, opening_weekend_percentage, rating, release_date, runtime, budget, worldwide_gross, spring, summer, winter, autumn, simultaneous_releases, G, NC-17, PG, PG-13, R, Unrated, Action, Adventure, Animation, Comedy, Concert, Crime, Documentary, Drama, Family, Fantasy, Horror, Independent, Musical, Romance, Sci-Fi, Thriller, War, Western, opening_weekend_gross_log, predicted, likely matches, likely_matches]
# Index: []
#
# [0 rows x 43 columns]

# %%
def m_diagnostic_plot(x, y):
    plt.figure(figsize=(10,2.5))
    rgr = LinearRegression()
    rgr.fit(x,y)
    pred = rgr.predict(x)

    res = y - pred
    plt.scatter(pred, res)
    plt.title("Residual plot")
    plt.xlabel("prediction")
    plt.ylabel("residuals")
    
    
def poly_diagnostic_plot(x, y):
    plt.figure(figsize=(10,2.5))
    PolynomialFeatures(degree=2)
    X_poly = poly.fit_transform(X)
    lm_poly = LinearRegression()
    lm_poly.fit(X_poly,y)
    pred = lm_poly.predict(X_poly)

    res = y - pred
    plt.scatter(pred, res, color='m')
    plt.title("Residual plot")
    plt.xlabel("prediction")
    plt.ylabel("residuals")

# %%
plt.figure(figsize=(6.5,5))
plt.scatter(X_test[:,0],y_test,color='darkgreen',label="Data", alpha=.1)
plt.plot(X_test.[:,0],lm.predict(X_test),color="red",label="Predicted Regression Line")

plt.xlabel("Space (sqft)", fontsize=15)
plt.ylabel("Price ($)", fontsize=15)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.legend()

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
plt.figure(figsize=(10,2.5))
rgr = LinearRegression()
rgr.fit(X_train,y_train)
pred = rgr.predict(X_train)

res = y_train - pred
plt.scatter(pred, res)
plt.title("Scorpion Plot")
plt.xlabel("prediction")
plt.ylabel("residuals")
# Out:
# Text(0,0.5,'residuals')

# %%
plt.figure(figsize=(10,2.5))
ridge = RidgeCV(cv=5)
ridge.fit(X_train,y_train)
pred = rgr.predict(X_train)

res = y_train - pred
plt.scatter(pred, res,color='green')
plt.plot()
plt.title("Residual Plot")
plt.xlabel("prediction")
plt.ylabel("residuals")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4134fe9a72b8> in <module>()
# ----> 1 plt.figure(figsize=(10,2.5))
#       2 ridge = RidgeCV(cv=5)
#       3 ridge.fit(X_train,y_train)
#       4 pred = rgr.predict(X_train)
#       5
#
# NameError: name 'plt' is not defined

# %%
luther.columns
# Out:
# Index(['domestic_gross', 'genre', 'movie_title', 'opening_weekend_gross',
#        'opening_weekend_percentage', 'rating', 'release_date', 'runtime',
#        'budget', 'worldwide_gross', 'spring', 'summer', 'winter', 'autumn',
#        'simultaneous_releases', 'G', 'NC-17', 'PG', 'PG-13', 'R', 'Unrated',
#        'Action', 'Adventure', 'Animation', 'Comedy', 'Concert', 'Crime',
#        'Documentary', 'Drama', 'Family', 'Fantasy', 'Horror', 'Independent',
#        'Musical', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western',
#        'opening_weekend_gross_log', 'predicted', 'likely matches',
#        'likely_matches'],
#       dtype='object')
